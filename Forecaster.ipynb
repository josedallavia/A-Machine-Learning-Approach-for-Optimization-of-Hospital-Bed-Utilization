# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import sys
import os
from thesis_lib.forecast import *
# some handy functions to use along widgets
from IPython.display import display, Markdown, clear_output
# widget packages
import ipywidgets as widgets
# Out:
# /Users/josefinadallavia/Documents/MIM/Tesis/AML-hospital

# %% [markdown]
# <img src="attachment:logo_title.jpg" width="300" align="right"/>

# %% [markdown]
# ### Discharges Forecaster

# %% [markdown]
# #### Instructions:
# Specify the desired date and then click on `Run Forecast`. You will get three estimates, with different confidence levels, of expected discharges for that date..
#
# If there is no data for the specified date an error message will be prompt.
#
# For more information visit visit:
# https://github.com/josedallavia/A-Machine-Learning-Approach-for-Prediction-of-Hospital-Bed-Availability'

# %%
calendar = widgets.DatePicker(
           description='Select Date')

# %%
calendar
# Out:
# DatePicker(value=None, description='Select Date')

# %%
button = widgets.Button(description='Run Forecast')
out = widgets.Output()
def on_button_clicked(_):
    os.chdir('/Users/josefinadallavia/Documents/MIM/Tesis/AML-hospital/')
    date = calendar.value
    forecast_discharges(date)
# linking button and function together using a button's method
button.on_click(on_button_clicked)
# displaying button and its output together
widgets.VBox([button,out])
# Out:
# ...
# Forecasting discharges for date: 2019-10-22
# With 95 % of confidence, number of discharges will be at least 6
# With 80 % of confidence, number of discharges will be at least 9
# With 70 % of confidence, number of discharges will be at least 10

# %% [markdown]
#                                 Josefina Dalla Via Monti
#                                 @github.com/josedallavia
