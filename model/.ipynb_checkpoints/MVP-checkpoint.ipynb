# %%
import os
import pandas as pd
from matplotlib import pyplot as plt

# %%
def load_datasets(parquets_folder,load_test=False):    
    
    path= parquets_folder+'/'
    
    filenames = ['hospital_train_data.parquet','hospital_val_data.parquet','hospital_test_data.parquet']
    
    
    for file in filenames:
        if not os.path.isfile(path+file):
            print(file, 'not available in the specified folder')
        else:
            if '_train_' in file and not load_test:
                print('Loading dataset: ',file)
                train_data = pd.read_parquet(path+file)
            elif '_val_' in file and not load_test:
                print('Loading dataset: ',file)
                val_data = pd.read_parquet(path+file)
            elif '_test_' in file and load_test:
                print('Loading dataset: ',file)
                test_data = pd.read_parquet(path+file)
        
    return (train_data,val_data) if not load_test else test_data

# %%
# %cd /Users/josefinadallavia/Documents/MIM/Tesis/A-Machine-Learning-Approach-for-Prediction-of-Hospital-Bed-Availability/
# Out:
# /Users/josefinadallavia/Documents/MIM/Tesis/A-Machine-Learning-Approach-for-Prediction-of-Hospital-Bed-Availability

# %%
train_set, val_set = load_datasets('data/hospital_dataset')
# Out:
# Loading dataset:  hospital_train_data.parquet
# Loading dataset:  hospital_val_data.parquet

# %%
pd.options.display.max_columns = None

# %%
train_set.head()
# Out:
#        admission_id        date  discharge  hosp_day_number  images_count  \
# 39305      522410-8  2018-11-10        0.0              8.0           0.0
# 297524     522272-6  2018-11-10        0.0              9.0           0.0
# 461820     523050-3  2018-11-10        1.0              1.0           0.0
# 133272     523047-3  2018-11-10        0.0              1.0           0.0
# 184562     522617-3  2018-11-10        0.0              5.0           0.0
#
#         images_cumulative  images_emergencies images_requester_roles  \
# 39305                 1.0                 0.0
# 297524                1.0                 0.0
# 461820                0.0                 0.0
# 133272                1.0                 0.0
# 184562                1.0                 0.0
#
#         images_requester_roles_count images_requesters  \
# 39305                            0.0
# 297524                           0.0
# 461820                           0.0
# 133272                           0.0
# 184562                           0.0
#
#         images_requesters_count images_studies_names images_study_types  \
# 39305                       0.0
# 297524                      0.0
# 461820                      0.0
# 133272                      0.0
# 184562                      0.0
#
#         images_study_types_count  labos_count  labos_cumulative  \
# 39305                        0.0          0.0              51.0
# 297524                       0.0          5.0              79.0
# 461820                       0.0          0.0               2.0
# 133272                       0.0          8.0              21.0
# 184562                       0.0          8.0              31.0
#
#         labos_emergencies labos_requester_roles  labos_requester_roles_count  \
# 39305                 0.0                                                0.0
# 297524                0.0        MEDICO DE PISO                          1.0
# 461820                0.0                                                0.0
# 133272                0.0        MEDICO DE PISO                          1.0
# 184562                0.0        MEDICO DE PISO                          1.0
#
#                       labos_requesters  labos_requesters_count  \
# 39305                                                      0.0
# 297524                  QUEIROLO ERIKA                     1.0
# 461820                                                     0.0
# 133272  ESPINOSA TRUJILLO LUIS ALFONSO                     1.0
# 184562           ALEGRE EDUARDO MATIAS                     1.0
#
#         labos_set_count  labos_set_cumulative  \
# 39305               0.0                   9.0
# 297524              1.0                  18.0
# 461820              0.0                   1.0
# 133272              1.0                   2.0
# 184562              1.0                   7.0
#
#                                       labos_studies_names patient_id  \
# 39305                                                      2997069-0
# 297524  GLUCOSA EN SANGRE,HEMOGRAMA,IONOGRAMA EN SANGR...  1245308-8
# 461820                                                     3612687-6
# 133272  GLUCOSA EN SANGRE,HEMOGRAMA,IONOGRAMA EN SANGR...  3789723-3
# 184562  GLUCOSA EN SANGRE,HEMOGRAMA,IONOGRAMA EN SANGR...  3430174-1
#
#        sector_stay  sectors_count sectors_last_sector  sectors_last_stay  \
# 39305                         0.0                 T19               17.0
# 297524                        0.0                 T16            14543.0
# 461820                        0.0                 T10               16.0
# 133272                        0.0                 UC3             3270.0
# 184562                        0.0                 T17               17.0
#
#        sectors_names surgeries_actual surgeries_anesthesia_types  \
# 39305
# 297524
# 461820
# 133272
# 184562
#
#        surgeries_bact_positive  surgeries_count  surgeries_cumulative  \
# 39305                                       0.0                   0.0
# 297524                                      0.0                   0.0
# 461820                                      0.0                   0.0
# 133272                                      0.0                   1.0
# 184562                                      0.0                   0.0
#
#        surgeries_injury_condition surgeries_post_surgery_condition  \
# 39305
# 297524
# 461820
# 133272
# 184562
#
#         surgeries_post_surgery_duration  surgeries_pre_surgery_duration  \
# 39305                               0.0                             0.0
# 297524                              0.0                             0.0
# 461820                              0.0                             0.0
# 133272                              0.0                             0.0
# 184562                              0.0                             0.0
#
#         surgeries_prep_duration surgeries_scheduled surgeries_scheduled_done  \
# 39305                       0.0
# 297524                      0.0
# 461820                      0.0
# 133272                      0.0
# 184562                      0.0
#
#        surgeries_services  surgeries_services_count  surgeries_surgery_delay  \
# 39305                                           0.0                      0.0
# 297524                                          0.0                      0.0
# 461820                                          0.0                      0.0
# 133272                                          0.0                      0.0
# 184562                                          0.0                      0.0
#
#         surgeries_surgery_duration surgeries_types  surgeries_types_count  \
# 39305                          0.0                                    0.0
# 297524                         0.0                                    0.0
# 461820                         0.0                                    0.0
# 133272                         0.0                                    0.0
# 184562                         0.0                                    0.0
#
#         birth_date gender                    insurance_entity entity_group  \
# 39305   1994-06-22      M  OSUTHGRA O.S PERSONAL GASTRONOMICO      BRISTOL
# 297524  1947-02-02      M  OSUTHGRA O.S PERSONAL GASTRONOMICO      BRISTOL
# 461820  1990-07-08      F  OSUTHGRA O.S PERSONAL GASTRONOMICO      BRISTOL
# 133272  1960-06-06      F                            I.O.M.A.           OS
# 184562  1953-08-04      M  OSUTHGRA O.S PERSONAL GASTRONOMICO      BRISTOL
#
#             origin admission_sector isolation  \
# 39305      Guardia              CEG      None
# 297524     Guardia              CEG      None
# 461820     Guardia              T10      None
# 133272  Programada              UC3      None
# 184562     Guardia              T17      None
#
#                  administrative_diagnosis            presumptive_dianogsis  \
# 39305        CELULITIS/ABSCESO DEL CUELLO         Otra Celulitis Y Absceso
# 297524       EMBOLIA Y TROMBOSIS ARTERIAL             No Especifica Codigo
# 461820                    POST QX CESAREA                  Cesarea Clasica
# 133272  NEFRECTOMIA PARCIAL LAPAROSCOPICA  Otra Operacion Sobre Riñon Ncoc
# 184562                   ABSCESO HEPATICO                 Absceso Hepatico
#
#              responsible_sector  emergency_service  new_born_weight  \
# 39305            CLINICA MEDICA         42010102.0              NaN
# 297524           CLINICA MEDICA         42010102.0              NaN
# 461820              OBSTETRICIA         42010106.0              NaN
# 133272                 UROLOGIA                NaN              NaN
# 184562  CIRUGIA GENERAL ADULTOS         42010102.0              NaN
#
#         new_born_gestation_age  PIM2TEP  high_risk_TEP  low_risk_TEP ARM_TEP  \
# 39305                        0      NaN            NaN           NaN    None
# 297524                       0      NaN            NaN           NaN    None
# 461820                       0      NaN            NaN           NaN    None
# 133272                       0      NaN            NaN           NaN    None
# 184562                       0      NaN            NaN           NaN    None
#
#        CEC_TEP           request_origin             request  \
# 39305     None                     None                None
# 297524    None                     None                None
# 461820    None  CENTRO DE SALUD PRIVADO  VICTOR VERGANI 830
# 133272    None                     None                None
# 184562    None                     None                None
#
#         request_diagnosis request_sector admission_date  patient_age
# 39305                None           None     2018-11-02           24
# 297524               None           None     2018-11-01           71
# 461820  RIESGO METABOLICO   NEONATOLOGIA     2018-11-09           28
# 133272               None           None     2018-11-09           58
# 184562               None           None     2018-11-05           65

# %%
train_set['admission_weekday'] = pd.to_datetime(train_set['admission_date']).dt.weekday.astype('str')
train_set['date_weekday'] = pd.to_datetime(train_set['date']).dt.weekday.astype('str')

# %%
val_set['admission_weekday'] = pd.to_datetime(val_set['admission_date']).dt.weekday.astype('str')
val_set['date_weekday'] = pd.to_datetime(val_set['date']).dt.weekday.astype('str')

# %%
categorical = []
numerical = []
for col in train_set:
    if train_set[col].dtype == 'object':
        if train_set[col].nunique() < 10:
            categorical.append(col)
    elif train_set[col].dtype in ['float', 'int']:
        numerical.append(col)

# %%
# Out:
#        admission_id        date  discharge  hosp_day_number  images_count  \
# 39305      522410-8  2018-11-10        0.0              8.0           0.0
# 297524     522272-6  2018-11-10        0.0              9.0           0.0
# 461820     523050-3  2018-11-10        1.0              1.0           0.0
# 133272     523047-3  2018-11-10        0.0              1.0           0.0
# 184562     522617-3  2018-11-10        0.0              5.0           0.0
# ...             ...         ...        ...              ...           ...
# 268631     466488-6  2017-01-01        0.0              0.0           1.0
# 67933      466511-5  2017-01-01        0.0              0.0           1.0
# 427949     466498-7  2017-01-01        0.0              0.0           4.0
# 42866      466476-9  2017-01-01        0.0              0.0           0.0
# 462869     466471-4  2017-01-01        0.0              0.0           5.0
#
#         images_cumulative  images_emergencies  \
# 39305                 1.0                 0.0
# 297524                1.0                 0.0
# 461820                0.0                 0.0
# 133272                1.0                 0.0
# 184562                1.0                 0.0
# ...                   ...                 ...
# 268631                1.0                 1.0
# 67933                 1.0                 1.0
# 427949                4.0                 0.0
# 42866                 0.0                 0.0
# 462869                5.0                 1.0
#
#                                    images_requester_roles  \
# 39305
# 297524
# 461820
# 133272
# 184562
# ...                                                   ...
# 268631                                     MEDICO DE PISO
# 67933                                   MEDICO DE GUARDIA
# 427949                      MEDICO DE PISO,MEDICO CIRUGIA
# 42866
# 462869  MEDICO DE PISO,JEFE DE DIA - DADO DE BAJA,ROTA...
#
#         images_requester_roles_count  \
# 39305                            0.0
# 297524                           0.0
# 461820                           0.0
# 133272                           0.0
# 184562                           0.0
# ...                              ...
# 268631                           1.0
# 67933                            1.0
# 427949                           2.0
# 42866                            0.0
# 462869                           4.0
#
#                                         images_requesters  \
# 39305
# 297524
# 461820
# 133272
# 184562
# ...                                                   ...
# 268631                            PEREZ CARDENAS MARJORIE
# 67933                                    TORRES FRANCISCO
# 427949             PUENTE KAROLA ADRIANA,SLUTZKY MAURICIO
# 42866
# 462869  VEDIA ANICETA,DENNER GERMAN,BERNAL ARAGON NEST...
#
#         images_requesters_count  \
# 39305                       0.0
# 297524                      0.0
# 461820                      0.0
# 133272                      0.0
# 184562                      0.0
# ...                         ...
# 268631                      1.0
# 67933                       1.0
# 427949                      2.0
# 42866                       0.0
# 462869                      5.0
#
#                                      images_studies_names  \
# 39305
# 297524
# 461820
# 133272
# 184562
# ...                                                   ...
# 268631       TORAX FRENTE Y PERFIL, RX DE (C/S TRAZ-RELL)
# 67933                              RX C/PORTATIL DE TORAX
# 427949  TORAX FRENTE Y PERFIL, RX DE (C/S TRAZ-RELL),T...
# 42866
# 462869  RX C/PORTATIL DE TORAX,ECO-DOPPLER COLOR CARDI...
#
#                                        images_study_types  \
# 39305
# 297524
# 461820
# 133272
# 184562
# ...                                                   ...
# 268631                                              RAYOS
# 67933                                               RAYOS
# 427949  RAYOS,TOMOGRAFIA COMPUTADA (TAC),RESONANCIA MA...
# 42866
# 462869    RAYOS,ECOCARDIOGRAMA,ELECTROCARDIOG. SERV. INT.
#
#         images_study_types_count  labos_count  labos_cumulative  \
# 39305                        0.0          0.0              51.0
# 297524                       0.0          5.0              79.0
# 461820                       0.0          0.0               2.0
# 133272                       0.0          8.0              21.0
# 184562                       0.0          8.0              31.0
# ...                          ...          ...               ...
# 268631                       1.0          6.0               6.0
# 67933                        1.0          7.0               7.0
# 427949                       4.0         11.0              11.0
# 42866                        0.0          6.0               6.0
# 462869                       3.0         27.0              27.0
#
#         labos_emergencies                              labos_requester_roles  \
# 39305                 0.0
# 297524                0.0                                     MEDICO DE PISO
# 461820                0.0
# 133272                0.0                                     MEDICO DE PISO
# 184562                0.0                                     MEDICO DE PISO
# ...                   ...                                                ...
# 268631                0.0                                     MEDICO DE PISO
# 67933                 7.0                                  MEDICO DE GUARDIA
# 427949                0.0                                     MEDICO DE PISO
# 42866                 0.0                                     MEDICO DE PISO
# 462869               12.0  MEDICO DE PISO,JEFE DE DIA - DADO DE BAJA,ROTANTE
#
#         labos_requester_roles_count  \
# 39305                           0.0
# 297524                          1.0
# 461820                          0.0
# 133272                          1.0
# 184562                          1.0
# ...                             ...
# 268631                          1.0
# 67933                           1.0
# 427949                          1.0
# 42866                           1.0
# 462869                          3.0
#
#                                          labos_requesters  \
# 39305
# 297524                                     QUEIROLO ERIKA
# 461820
# 133272                     ESPINOSA TRUJILLO LUIS ALFONSO
# 184562                              ALEGRE EDUARDO MATIAS
# ...                                                   ...
# 268631                            PEREZ CARDENAS MARJORIE
# 67933                                    TORRES FRANCISCO
# 427949                              PUENTE KAROLA ADRIANA
# 42866                                         ALDAO SOFIA
# 462869  VEDIA ANICETA,DENNER GERMAN,BERNAL ARAGON NEST...
#
#         labos_requesters_count  labos_set_count  labos_set_cumulative  \
# 39305                      0.0              0.0                   9.0
# 297524                     1.0              1.0                  18.0
# 461820                     0.0              0.0                   1.0
# 133272                     1.0              1.0                   2.0
# 184562                     1.0              1.0                   7.0
# ...                        ...              ...                   ...
# 268631                     1.0              1.0                   1.0
# 67933                      1.0              1.0                   1.0
# 427949                     1.0              2.0                   2.0
# 42866                      1.0              1.0                   1.0
# 462869                     4.0              4.0                   4.0
#
#                                       labos_studies_names patient_id  \
# 39305                                                      2997069-0
# 297524  GLUCOSA EN SANGRE,HEMOGRAMA,IONOGRAMA EN SANGR...  1245308-8
# 461820                                                     3612687-6
# 133272  GLUCOSA EN SANGRE,HEMOGRAMA,IONOGRAMA EN SANGR...  3789723-3
# 184562  GLUCOSA EN SANGRE,HEMOGRAMA,IONOGRAMA EN SANGR...  3430174-1
# ...                                                   ...        ...
# 268631  GLUCOSA EN SANGRE,HEMOGRAMA,IONOGRAMA EN SANGR...  2986999-9
# 67933   COAGULOGRAMA BASICO,GLUCOSA EN SANGRE,HEMOGRAM...  3714635-1
# 427949  COAGULOGRAMA BASICO,GLUCOSA EN SANGRE,HEMOGRAM...  3714613-6
# 42866   COAGULOGRAMA BASICO,GLUCOSA EN SANGRE,HEMOGRAM...  2951027-4
# 462869  COAGULOGRAMA BASICO,CPK,GLUCOSA EN SANGRE,HEMO...  3714597-2
#
#          sector_stay  sectors_count sectors_last_sector  sectors_last_stay  \
# 39305                           0.0                 T19               17.0
# 297524                          0.0                 T16            14543.0
# 461820                          0.0                 T10               16.0
# 133272                          0.0                 UC3             3270.0
# 184562                          0.0                 T17               17.0
# ...              ...            ...                 ...                ...
# 268631          23.0            1.0                 T13               23.0
# 67933          129.0            1.0                 EME              129.0
# 427949        1556.0            1.0                 EME             1556.0
# 42866           11.0            1.0                 T12               11.0
# 462869  278.0,1711.0            2.0                 UCO             1711.0
#
#        sectors_names surgeries_actual surgeries_anesthesia_types  \
# 39305
# 297524
# 461820
# 133272
# 184562
# ...              ...              ...                        ...
# 268631           T13
# 67933            EME
# 427949           EME
# 42866            T12
# 462869       EME,UCO
#
#        surgeries_bact_positive  surgeries_count  surgeries_cumulative  \
# 39305                                       0.0                   0.0
# 297524                                      0.0                   0.0
# 461820                                      0.0                   0.0
# 133272                                      0.0                   1.0
# 184562                                      0.0                   0.0
# ...                        ...              ...                   ...
# 268631                                      0.0                   0.0
# 67933                                       0.0                   0.0
# 427949                                      0.0                   0.0
# 42866                                       0.0                   0.0
# 462869                                      0.0                   0.0
#
#        surgeries_injury_condition surgeries_post_surgery_condition  \
# 39305
# 297524
# 461820
# 133272
# 184562
# ...                           ...                              ...
# 268631
# 67933
# 427949
# 42866
# 462869
#
#         surgeries_post_surgery_duration  surgeries_pre_surgery_duration  \
# 39305                               0.0                             0.0
# 297524                              0.0                             0.0
# 461820                              0.0                             0.0
# 133272                              0.0                             0.0
# 184562                              0.0                             0.0
# ...                                 ...                             ...
# 268631                              0.0                             0.0
# 67933                               0.0                             0.0
# 427949                              0.0                             0.0
# 42866                               0.0                             0.0
# 462869                              0.0                             0.0
#
#         surgeries_prep_duration surgeries_scheduled surgeries_scheduled_done  \
# 39305                       0.0
# 297524                      0.0
# 461820                      0.0
# 133272                      0.0
# 184562                      0.0
# ...                         ...                 ...                      ...
# 268631                      0.0
# 67933                       0.0
# 427949                      0.0
# 42866                       0.0
# 462869                      0.0
#
#        surgeries_services  surgeries_services_count  surgeries_surgery_delay  \
# 39305                                           0.0                      0.0
# 297524                                          0.0                      0.0
# 461820                                          0.0                      0.0
# 133272                                          0.0                      0.0
# 184562                                          0.0                      0.0
# ...                   ...                       ...                      ...
# 268631                                          0.0                      0.0
# 67933                                           0.0                      0.0
# 427949                                          0.0                      0.0
# 42866                                           0.0                      0.0
# 462869                                          0.0                      0.0
#
#         surgeries_surgery_duration surgeries_types  surgeries_types_count  \
# 39305                          0.0                                    0.0
# 297524                         0.0                                    0.0
# 461820                         0.0                                    0.0
# 133272                         0.0                                    0.0
# 184562                         0.0                                    0.0
# ...                            ...             ...                    ...
# 268631                         0.0                                    0.0
# 67933                          0.0                                    0.0
# 427949                         0.0                                    0.0
# 42866                          0.0                                    0.0
# 462869                         0.0                                    0.0
#
#         birth_date gender                        insurance_entity  \
# 39305   1994-06-22      M      OSUTHGRA O.S PERSONAL GASTRONOMICO
# 297524  1947-02-02      M      OSUTHGRA O.S PERSONAL GASTRONOMICO
# 461820  1990-07-08      F      OSUTHGRA O.S PERSONAL GASTRONOMICO
# 133272  1960-06-06      F                                I.O.M.A.
# 184562  1953-08-04      M      OSUTHGRA O.S PERSONAL GASTRONOMICO
# ...            ...    ...                                     ...
# 268631  1958-01-11      F  HOMINIS-PLAN DE SALUD SANATORIO GUEMES
# 67933   1939-07-13      M                             PAMI UGL VI
# 427949  1936-02-25      F                                I.O.M.A.
# 42866   1974-11-02      M      OSUTHGRA O.S PERSONAL GASTRONOMICO
# 462869  1942-09-13      F                             PAMI UGL VI
#
#        entity_group       origin admission_sector isolation  \
# 39305       BRISTOL      Guardia              CEG         0
# 297524      BRISTOL      Guardia              CEG         0
# 461820      BRISTOL      Guardia              T10         0
# 133272           OS   Programada              UC3         0
# 184562      BRISTOL      Guardia              T17         0
# ...             ...          ...              ...       ...
# 268631      HOMINIS      Guardia              T13         0
# 67933          PAMI  Emergencias              EME         0
# 427949           OS  Emergencias              EME         0
# 42866       BRISTOL      Guardia              T12         0
# 462869         PAMI  Emergencias              EME         *
#
#                         administrative_diagnosis  \
# 39305               CELULITIS/ABSCESO DEL CUELLO
# 297524              EMBOLIA Y TROMBOSIS ARTERIAL
# 461820                           POST QX CESAREA
# 133272         NEFRECTOMIA PARCIAL LAPAROSCOPICA
# 184562                          ABSCESO HEPATICO
# ...                                          ...
# 268631                   DIVERTICULITIS DE COLON
# 67933   IC DESCOM. AP: ACO DERRAME PERICARDIO SE
# 427949                                       HTA
# 42866                           DOLOR  ABDOMIANL
# 462869                          DIF RESPIRATORIA
#
#                             presumptive_dianogsis       responsible_sector  \
# 39305                    Otra Celulitis Y Absceso           CLINICA MEDICA
# 297524                       No Especifica Codigo           CLINICA MEDICA
# 461820                            Cesarea Clasica              OBSTETRICIA
# 133272            Otra Operacion Sobre Riñon Ncoc                 UROLOGIA
# 184562                           Absceso Hepatico  CIRUGIA GENERAL ADULTOS
# ...                                           ...                      ...
# 268631                       No Especifica Codigo  CIRUGIA GENERAL ADULTOS
# 67933                      Insuficiencia Cardiaca           CLINICA MEDICA
# 427949  Bloqueo Auriculo Ventricular De Mobitz Ii           CLINICA MEDICA
# 42866                        No Especifica Codigo  CIRUGIA GENERAL ADULTOS
# 462869                       No Especifica Codigo      CARDIOLOGIA ADULTOS
#
#         emergency_service  new_born_weight  new_born_gestation_age  PIM2TEP  \
# 39305          42010102.0              0.0                       0      0.0
# 297524         42010102.0              0.0                       0      0.0
# 461820         42010106.0              0.0                       0      0.0
# 133272                0.0              0.0                       0      0.0
# 184562         42010102.0              0.0                       0      0.0
# ...                   ...              ...                     ...      ...
# 268631                0.0              0.0                       0      0.0
# 67933                 0.0              0.0                       0      0.0
# 427949                0.0              0.0                       0      0.0
# 42866                 0.0              0.0                       0      0.0
# 462869                0.0              0.0                       0      0.0
#
#         high_risk_TEP  low_risk_TEP ARM_TEP CEC_TEP           request_origin  \
# 39305             0.0           0.0       0       0                        0
# 297524            0.0           0.0       0       0                        0
# 461820            0.0           0.0       0       0  CENTRO DE SALUD PRIVADO
# 133272            0.0           0.0       0       0                        0
# 184562            0.0           0.0       0       0                        0
# ...               ...           ...     ...     ...                      ...
# 268631            0.0           0.0       0       0                        0
# 67933             0.0           0.0       0       0                        0
# 427949            0.0           0.0       0       0                        0
# 42866             0.0           0.0       0       0                        0
# 462869            0.0           0.0       0       0                        0
#
#                    request  request_diagnosis request_sector admission_date  \
# 39305                    0                  0              0     2018-11-02
# 297524                   0                  0              0     2018-11-01
# 461820  VICTOR VERGANI 830  RIESGO METABOLICO   NEONATOLOGIA     2018-11-09
# 133272                   0                  0              0     2018-11-09
# 184562                   0                  0              0     2018-11-05
# ...                    ...                ...            ...            ...
# 268631                   0                  0              0     2017-01-01
# 67933                    0                  0              0     2017-01-01
# 427949                   0                  0              0     2017-01-01
# 42866                    0                  0              0     2017-01-01
# 462869                   0                  0              0     2017-01-01
#
#         patient_age admission_weekday date_weekday
# 39305            24                 4            5
# 297524           71                 3            5
# 461820           28                 4            5
# 133272           58                 4            5
# 184562           65                 0            5
# ...             ...               ...          ...
# 268631           58                 6            6
# 67933            77                 6            6
# 427949           80                 6            6
# 42866            42                 6            6
# 462869           74                 6            6
#
# [319150 rows x 74 columns]

# %%
categorical
# Out:
# ['gender',
#  'entity_group',
#  'origin',
#  'isolation',
#  'ARM_TEP',
#  'CEC_TEP',
#  'request_sector',
#  'admission_weekday',
#  'date_weekday']

# %%
numerical
# Out:
# ['discharge',
#  'hosp_day_number',
#  'images_count',
#  'images_cumulative',
#  'images_emergencies',
#  'images_requester_roles_count',
#  'images_requesters_count',
#  'images_study_types_count',
#  'labos_count',
#  'labos_cumulative',
#  'labos_emergencies',
#  'labos_requester_roles_count',
#  'labos_requesters_count',
#  'labos_set_count',
#  'labos_set_cumulative',
#  'sectors_count',
#  'sectors_last_stay',
#  'surgeries_count',
#  'surgeries_cumulative',
#  'surgeries_post_surgery_duration',
#  'surgeries_pre_surgery_duration',
#  'surgeries_prep_duration',
#  'surgeries_services_count',
#  'surgeries_surgery_delay',
#  'surgeries_surgery_duration',
#  'surgeries_types_count',
#  'emergency_service',
#  'new_born_weight',
#  'new_born_gestation_age',
#  'PIM2TEP',
#  'high_risk_TEP',
#  'low_risk_TEP',
#  'patient_age']

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelBinarizer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class CategoricalSelector(BaseEstimator, TransformerMixin):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    Use on categorical columns in the data
    """
    def __init__(self, keys):
        self.keys = keys

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X[self.keys]
    
class NumberSelector(BaseEstimator, TransformerMixin):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    Use on numeric columns in the data
    """
    def __init__(self, key):
        self.key = key

    def fit(self, X, y=None):
        return self.astype(str)

    def transform(self, X):
        return X[[self.key]]

# %%
from sklearn.pipeline import Pipeline

# %%
categories = Pipeline([
                ('selector', CategoricalSelector(keys=categorical)),
                ('binarizer', OneHotEncoder())
            ])

# %%
from sklearn.preprocessing import StandardScaler

numbers =  Pipeline([
                ('selector', NumberSelector(key='hosp_day_number')),
                ('standard', StandardScaler())
            ])

# %%
from sklearn.pipeline import FeatureUnion

feats = FeatureUnion([('categories', categories), 
                      ('numerical', numbers)])

# %%
feature_processing = Pipeline([('feats', feats)])
feature_processing.fit_transform(train_set.fillna(0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-5f2bce24de51> in <module>()
#       1 feature_processing = Pipeline([('feats', feats)])
# ----> 2 feature_processing.fit_transform(train_set.fillna(0))
#
# /anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     298         Xt, fit_params = self._fit(X, y, **fit_params)
#     299         if hasattr(last_step, 'fit_transform'):
# --> 300             return last_step.fit_transform(Xt, y, **fit_params)
#     301         elif last_step is None:
#     302             return Xt
#
# /anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     791             delayed(_fit_transform_one)(trans, X, y, weight,
#     792                                         **fit_params)
# --> 793             for name, trans, weight in self._iter())
#     794
#     795         if not result:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     915             # remaining jobs.
#     916             self._iterating = False
# --> 917             if self.dispatch_one_batch(iterator):
#     918                 self._iterating = self._original_iterator is not None
#     919
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, **fit_params)
#     612 def _fit_transform_one(transformer, X, y, weight, **fit_params):
#     613     if hasattr(transformer, 'fit_transform'):
# --> 614         res = transformer.fit_transform(X, y, **fit_params)
#     615     else:
#     616         res = transformer.fit(X, y, **fit_params).transform(X)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     298         Xt, fit_params = self._fit(X, y, **fit_params)
#     299         if hasattr(last_step, 'fit_transform'):
# --> 300             return last_step.fit_transform(Xt, y, **fit_params)
#     301         elif last_step is None:
#     302             return Xt
#
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py in fit_transform(self, X, y)
#     514                 self._categorical_features, copy=True)
#     515         else:
# --> 516             return self.fit(X).transform(X)
#     517
#     518     def _legacy_transform(self, X):
#
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py in fit(self, X, y)
#     425             return self
#     426         else:
# --> 427             self._fit(X, handle_unknown=self.handle_unknown)
#     428             return self
#     429
#
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py in _fit(self, X, handle_unknown)
#      78             Xi = X[:, i]
#      79             if self._categories == 'auto':
# ---> 80                 cats = _encode(Xi)
#      81             else:
#      82                 cats = np.array(self._categories[i], dtype=X.dtype)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in _encode(values, uniques, encode)
#     106     """
#     107     if values.dtype == object:
# --> 108         return _encode_python(values, uniques, encode)
#     109     else:
#     110         return _encode_numpy(values, uniques, encode)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in _encode_python(values, uniques, encode)
#      61     # only used in _encode below, see docstring there for details
#      62     if uniques is None:
# ---> 63         uniques = sorted(set(values))
#      64         uniques = np.array(uniques, dtype=values.dtype)
#      65     if encode:
#
# TypeError: '<' not supported between instances of 'str' and 'int'
