# %% [markdown]
# # Data Quality Reports

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %cd /Users/josefinadallavia/Documents/MIM/Tesis/AML-hospital/
# Out:
# /Users/josefinadallavia/Documents/MIM/Tesis/AML-hospital

# %%
import pandas as pd
import os
import shutil
import matplotlib.pyplot as plt 
import thesis_lib
from datetime import datetime, date
pd.set_option('display.max_columns', None)  
from thesis_lib.data_processing import *
from thesis_lib.visual import *
from thesis_lib.dataset import *
from thesis_lib.quality import *
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from math import ceil
from numpy import nan

# %% [markdown]
# ### Admissions dataset Quality Report

# %%
# %%capture
admissions = Dataset('admissions')

# %%
admissions.get_quality_report(report_type='full')
# Out:
# Getting full quality report for: admissions dataset...
#  	 CATEGORICAL VARIABLES:  62
# 	 Getting tabular report for categorical variables...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>variable</th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#       <th>missings</th>
#       <th>missings %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>admissions</td>
#       <td>admission_id</td>
#       <td>87720</td>
#       <td>87720</td>
#       <td>480806-2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>admissions</td>
#       <td>patient_id</td>
#       <td>87720</td>
#       <td>64156</td>
#       <td>3727595-3</td>
#       <td>89</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>admissions</td>
# ...

# %% [markdown]
# ### Surgeries dataset Quality Report

# %%
# %%capture
surgeries = Dataset('surgeries')

# %%
surgeries.get_quality_report(report_type='full')
# Out:
# Getting full quality report for: surgeries dataset...
#  	 CATEGORICAL VARIABLES:  61
# 	 Getting tabular report for categorical variables...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>variable</th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#       <th>missings</th>
#       <th>missings %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>surgeries</td>
#       <td>operating_room</td>
#       <td>66750</td>
#       <td>25</td>
#       <td>16</td>
#       <td>13698</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>surgeries</td>
#       <td>surgery_date</td>
#       <td>66750</td>
#       <td>1064</td>
#       <td>2019-10-29</td>
#       <td>115</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>surgeries</td>
# ...

# %% [markdown]
# ### Laboratory dataset Quality Report

# %%
# %%capture
laboratory = Dataset('laboratory')

# %%
laboratory.get_quality_report(report_type='full')
# Out:
# Getting full quality report for: laboratory dataset...
#  	 CATEGORICAL VARIABLES:  20
# 	 Getting tabular report for categorical variables...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>variable</th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#       <th>missings</th>
#       <th>missings %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>laboratory</td>
#       <td>labo_id</td>
#       <td>3086085</td>
#       <td>572502</td>
#       <td>44194707</td>
#       <td>35</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>laboratory</td>
#       <td>labo_pun</td>
#       <td>3086085</td>
#       <td>572502</td>
#       <td>44194368</td>
#       <td>35</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>laboratory</td>
# ...

# %% [markdown]
# ### Images dataset Quality Report

# %%
# %%capture
images = Dataset('images')

# %%
images.get_quality_report(report_type='full')
# Out:
# Getting full quality report for: images dataset...
#  	 CATEGORICAL VARIABLES:  20
# 	 Getting tabular report for categorical variables...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>variable</th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#       <th>missings</th>
#       <th>missings %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>images</td>
#       <td>image_id</td>
#       <td>350403</td>
#       <td>311873</td>
#       <td>44093706</td>
#       <td>11</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>images</td>
#       <td>image_pun</td>
#       <td>350403</td>
#       <td>311873</td>
#       <td>44093370</td>
#       <td>11</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>images</td>
# ...

# %% [markdown]
# ### Sectors admissions dataset Quality Report

# %%
# %%capture
sectors_admissions = Dataset('sectors_admissions')

# %%
sectors_admissions.get_quality_report(report_type='categorical')
# Out:
# Getting categorical quality report for: sectors_admissions dataset...
# 	 Getting tabular report for categorical variables...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>variable</th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#       <th>missings</th>
#       <th>missings %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>sectors_admissions</td>
#       <td>admission_id</td>
#       <td>154481</td>
#       <td>89921</td>
#       <td>528675-7</td>
#       <td>22</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>sectors_admissions</td>
#       <td>patient_id</td>
#       <td>154481</td>
#       <td>65595</td>
#       <td>3727595-3</td>
#       <td>99</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %% [markdown]
# ### Hospital sectors dataset Quality Report

# %%
# %%capture
hospital_sectors = Dataset('hospital_sectors')

# %%
hospital_sectors.get_quality_report(report_type='categorical')
# Out:
# Getting categorical quality report for: hospital_sectors dataset...
# 	 Getting tabular report for categorical variables...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>variable</th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#       <th>missings</th>
#       <th>missings %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>hospital_sectors</td>
#       <td>sector_code</td>
#       <td>36</td>
#       <td>36</td>
#       <td>PQU</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>hospital_sectors</td>
#       <td>sector_name</td>
#       <td>36</td>
#       <td>36</td>
#       <td>HEMOTERAPIA 4 SS TORRE</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>hospital_sectors</td>
# ...
