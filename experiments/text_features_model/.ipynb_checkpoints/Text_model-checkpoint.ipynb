# %% [markdown]
# # Model Selection

# %% [markdown]
# The objective of this notebook is to build a very first ent to end Machine Learning model to predict the probability of a patient being discharged on a particular day.
#
# We'll use the dataset generated by the `dataset` job of the ETL folder.
#
# At this instance, the focus won't be on model performance but rather on understanding the value potential of the available data and the speedness of the solution.

# %%
# %cd /Users/josefinadallavia/Documents/MIM/Tesis/AML-hospital
# Out:
# /Users/josefinadallavia/Documents/MIM/Tesis/AML-hospital

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
from matplotlib import pyplot as plt   
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from thesis_lib.utils import * 
from thesis_lib.modelling.data import *
from thesis_lib.modelling.model import *
# Out:
# /Users/josefinadallavia/opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /Users/josefinadallavia/opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /Users/josefinadallavia/opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data = Data().load('data/hospital_dataset')
variables = data.get_variables_dict()
data.get_stats()
# Out:
# Loading dataset:  hospital_train_data.parquet
# Loading dataset:  hospital_val_data.parquet
# Loading dataset:  hospital_test_data.parquet
# dataset_type         train         val        test
# n_observations      319150       33482       33309
# relative_size      0.82694   0.0867542   0.0863059
# n_cols                  71          71          71
# positives            42697        4555        4507
# negatives           276453       28927       28802
# positive_prop     0.133783    0.136043    0.135309
# negative_prop     0.866217    0.863957    0.864691
# min_date        2017-01-01  2018-11-11  2018-11-11
# max_date        2018-11-10  2019-11-11  2019-11-11

# %%
sequence_features = ['labos_studies_names','sectors_names','images_study_types','surgeries_types',
                    'surgeries_injury_condition','surgeries_post_surgery_condition','surgeries_anesthesia_types']

# %%
text_features = ['administrative_diagnosis','presumptive_dianogsis','images_studies_names',
                'surgeries_actual']

# %%
text_features = ['labos_studies_names','administrative_diagnosis','presumptive_dianogsis',
                  'sectors_names','images_studies_names','images_study_types','surgeries_types']

# %%
categorical_features = ['date_weekday',
 'request_origin',
 'origin',
 'entity_group',
 'gender',
 'request_sector',
 'insurance_entity',
 'admission_sector',
 'emergency_service',
 'isolation',
 'ARM_TEP',
 'CEC_TEP',
 'request_sector',
 'date_weekday',
 'admission_weekday',
 'date_month',
 'admission_month']

# %%
numerical_features = ['PIM2TEP',
 'emergency_service',
 'high_risk_TEP',
 'hosp_day_number',
 'images_count',
 'images_cumulative',
 'images_emergencies',
 'images_requester_roles_count',
 'images_requesters_count',
 'images_study_types_count',
 'labos_count',
 'labos_cumulative',
 'labos_emergencies',
 'labos_requester_roles_count',
 'labos_requesters_count',
 'labos_set_count',
 'labos_set_cumulative',
 'low_risk_TEP',
 'new_born_gestation_age',
 'new_born_weight',
 'patient_age',
 'sectors_count',
 'sectors_last_stay',
 'surgeries_count',
 'surgeries_cumulative',
 'surgeries_post_surgery_duration',
 'surgeries_pre_surgery_duration',
 'surgeries_prep_duration',
 'surgeries_services_count',
 'surgeries_surgery_delay',
 'surgeries_surgery_duration',
 'surgeries_types_count']

# %% [markdown]
# ### Text only

# %%
model_params = {'classifier': 'lgbm',
               'accepts_sparse': True,
                #'categorical_features' : categorical_features ,
                #'numerical_features' : numerical_features,
               'text_features': text_features,
               # 'sequence_features':sequence_features
               }

# %%
lgbm_text_features = Model(**model_params)
lgbm_text_features.transform(data)
# Out:
# Fitting pipeline...
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# Transforming data...
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings

# %%
lgbm_text_features.fit_classifier()
# Out:
# Training classifier
# /Users/josefinadallavia/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [10]	training_set's auc: 0.744599	validation_set's auc: 0.73211
# [20]	training_set's auc: 0.75811	validation_set's auc: 0.743081
# [30]	training_set's auc: 0.766255	validation_set's auc: 0.748389
# [40]	training_set's auc: 0.773716	validation_set's auc: 0.753724
# [50]	training_set's auc: 0.779281	validation_set's auc: 0.757671
# [60]	training_set's auc: 0.783543	validation_set's auc: 0.759906
# [70]	training_set's auc: 0.787122	validation_set's auc: 0.761852
# [80]	training_set's auc: 0.790305	validation_set's auc: 0.762845
# [90]	training_set's auc: 0.793452	validation_set's auc: 0.764058
# [100]	training_set's auc: 0.796188	validation_set's auc: 0.765181

# %%
lgbm_text_features.get_performance_metrics()
# Out:
# training AUC ROC score:  0.7961949913149796
# validation AUC ROC score:  0.7651814475114066
# relative over-fitting:  0.038952196562241206

# %% [markdown]
# ### Sequence only

# %%
model_params = {'classifier': 'lgbm',
               'accepts_sparse': True,
                #'categorical_features' : categorical_features ,
                #'numerical_features' : numerical_features,
               #'text_features': text_features,
                'sequence_features':sequence_features
               }

# %%
lgbm_seq_features = Model(**model_params)
lgbm_seq_features.transform(data)
lgbm_seq_features.fit_classifier()
# Out:
# Fitting pipeline...
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# Transforming data...
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# Training classifier
# /Users/josefinadallavia/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [10]	training_set's auc: 0.698384	validation_set's auc: 0.684289
# [20]	training_set's auc: 0.702971	validation_set's auc: 0.687349
# [30]	training_set's auc: 0.706452	validation_set's auc: 0.689848
# [40]	training_set's auc: 0.708328	validation_set's auc: 0.691168
# [50]	training_set's auc: 0.710352	validation_set's auc: 0.692952
# [60]	training_set's auc: 0.712315	validation_set's auc: 0.693927
# [70]	training_set's auc: 0.714104	validation_set's auc: 0.695159
# [80]	training_set's auc: 0.715335	validation_set's auc: 0.695798
# [90]	training_set's auc: 0.71717	validation_set's auc: 0.696845
# [100]	training_set's auc: 0.718194	validation_set's auc: 0.696757

# %%
lgbm_seq_features.get_performance_metrics()
# Out:
# training AUC ROC score:  0.7181886175411276
# validation AUC ROC score:  0.696757157395749
# relative over-fitting:  0.029840991101688377

# %% [markdown]
# ### Sequence + text

# %%
model_params = {'classifier': 'lgbm',
               'accepts_sparse': True,
                #'categorical_features' : categorical_features ,
                #'numerical_features' : numerical_features,
               'text_features': text_features,
                'sequence_features':sequence_features
               }

# %%
lgbm_comb_text_features = Model(**model_params)
lgbm_comb_text_features.transform(data)
lgbm_comb_text_features.fit_classifier()
# Out:
# Fitting pipeline...
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# 	 Preprocessing data
# Transforming data...
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming text features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# 	 Transforming sequence features
# 	 Preprocessing data
# 	 Transforming text features with TF-IDF embeddings
# Training classifier
# /Users/josefinadallavia/opt/anaconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [10]	training_set's auc: 0.747315	validation_set's auc: 0.733948
# [20]	training_set's auc: 0.759353	validation_set's auc: 0.744135
# [30]	training_set's auc: 0.76898	validation_set's auc: 0.750599
# [40]	training_set's auc: 0.776421	validation_set's auc: 0.756923
# [50]	training_set's auc: 0.781805	validation_set's auc: 0.760572
# [60]	training_set's auc: 0.786117	validation_set's auc: 0.763523
# [70]	training_set's auc: 0.789903	validation_set's auc: 0.765428
# [80]	training_set's auc: 0.793237	validation_set's auc: 0.766554
# [90]	training_set's auc: 0.796226	validation_set's auc: 0.767997
# [100]	training_set's auc: 0.7989	validation_set's auc: 0.769821

# %%
lgbm_comb_text_features.get_performance_metrics()
# Out:
# training AUC ROC score:  0.7989000926246709
# validation AUC ROC score:  0.7698209623171572
# relative over-fitting:  0.03639895723629015

# %%
lgbm_comb_text_features.plot_feature_importance(50)

# %%
lgbm_param_grid = {'max_depth': [3,7,10],
                  'learning_rate': [0.1,0.01,0.001,0.0001],
                  'num_iterations': [50,100,150,200,250]}

# %%
lgbm_text_features.optimize_hyperparams(params_dict=lgbm_param_grid,
                                         n_folds=3,n_iter=5,
                                         search_type='grid')
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.

# %%
exp_results = lgbm_text_features.get_model_selection_results()

# %%
exp_results.to_csv('experiments/lgb_text_features_grid_search_results.csv')

# %%
best_params = lgbm_text_features.model_selection.best_params_
best_params

# %%
lgbm_text_features.fit_best_classifier()

# %%
lgbm_text_features.get_performance_metrics()
